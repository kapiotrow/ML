# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
X, y= make_blobs(n_samples=210, centers=3, n_features=2, cluster_std=0.5, shuffle=True, random_state=0)
plt.scatter(X[:,0], X[:,1], c='red', marker='x')

# %% [markdown]
# ## Zadanie 1

# %%
km = KMeans(n_clusters=3, random_state=0, init="random").fit(X)
km.labels_

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=km.labels_, cmap=plt.cm.prism) 
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')
# Out:
# Text(0, 0.5, 'X1')

# %% [markdown]
# ## Zadanie 2

# %%
X, y= make_blobs(n_samples=280, centers=5, n_features=2, cluster_std=0.8, shuffle=True, random_state=0)
plt.scatter(X[:,0], X[:,1], c='red', marker='x')

# %% [markdown]
# Dopasowanie KMeans do rzeczywistej liczby klastrów:

# %%
km = KMeans(n_clusters=5, random_state=0, init="random").fit(X)
km.labels_

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=km.labels_, cmap=plt.cm.prism) 
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')

print(km.inertia_)
# Out:
# 352.36314504213306

# %% [markdown]
# Dopasowanie KMEans dla mniejszej liczby klastrów:

# %%
km = KMeans(n_clusters=3, random_state=0, init="random").fit(X)
km.labels_

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=km.labels_, cmap=plt.cm.prism) 
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')

print(km.inertia_)
# Out:
# 1087.1863051579696

# %% [markdown]
# ## Zadanie 3

# %%
X, y= make_blobs(n_samples=280, centers=5, n_features=2, cluster_std=0.9, shuffle=True, random_state=0)
plt.scatter(X[:,0], X[:,1], c='red', marker='x')

# %%
kmpp = KMeans(n_clusters=5, random_state=0, init='k-means++').fit(X)
kmpp.labels_

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=kmpp.labels_, cmap=plt.cm.prism) 
plt.scatter(kmpp.cluster_centers_[:, 0], kmpp.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')

print("k-means++: ",kmpp.inertia_)

km = KMeans(n_clusters=5, random_state=0, init='random').fit(X)
km.labels_

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=km.labels_, cmap=plt.cm.prism) 
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')

print(km.inertia_)
# Out:
# k-means++:  434.9958969809552
# 434.9958969809552

# %%
X, y= make_blobs(n_samples=280, centers=5, n_features=2, cluster_std=1.5, shuffle=True, random_state=0)
plt.scatter(X[:,0], X[:,1], c='red', marker='x')

# %%
kmpp = KMeans(n_clusters=5, random_state=0, init='k-means++').fit(X)
kmpp.labels_

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=kmpp.labels_, cmap=plt.cm.prism) 
plt.scatter(kmpp.cluster_centers_[:, 0], kmpp.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')

print("k-means++: ",kmpp.inertia_)

km = KMeans(n_clusters=5, random_state=0, init='random').fit(X)
km.labels_

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=km.labels_, cmap=plt.cm.prism) 
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')

print(km.inertia_)
# Out:
# k-means++:  1028.3759273204814
# 1025.5047719635613

# %% [markdown]
# ## Zadanie 4

# %%
X, y= make_blobs(n_samples=280, centers=5, n_features=2, cluster_std=0.9, shuffle=True, random_state=0)

inertia = []
ks = list(range(1, 11))
for k in ks:
    km = KMeans(n_clusters=k, random_state=0, init='random').fit(X)
    inertia.append(km.inertia_)

plt.plot(ks, inertia)
